# %%
import pandas as pd
import numpy as np

import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/transaction_data2.csv")
# Out:
# /tmp/ipykernel_44768/1969689443.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/transaction_data2.csv")

# %%
data
# Out:
#            id  account_id                              slug  \
# 0      138844      405126  M0WCFMgrAOY66j4XihFfWjTnXiOcGYAy
# 1      138843      378829  Kap6fl4YUMQXbQD4RiOqmzFFRqyF2KNC
# 2      138842      405469  20q6pKWEOdisOjnqIOmydvCTYF2wdf1Z
# 3      138841        2262  lVBB1Uvu4xqYnF3wDbP2ueWbWPcxwpWr
# 4      138840      402063  XptuuMZBfwxSnSFeDelHpJIVtuByYQHq
# ...       ...         ...                               ...
# 99995   38015      364922  XQa3NV0fInsEeGFVDR4McMYmh0slrOrd
# 99996   38014      364922  ks0qb148Mi7hxEZJiWsi59lVpJm7bOjr
# 99997   38013      353700  1sqAv41bna2dZex9UOfrZR8zcsIUSoxW
# 99998   38012      178277  qpyGgmSTFtRfqc1UBfULF8Y6pnhVET5w
# 99999   38011      353700  OQLhFvmlLhS1a2GtsaEQuvbhwERU9iyO
#
#                transaction_no    amount  bank_id  account_no  \
# 0      VFW2311071357823105808  500000.0       34  8069057349
# 1      VFW2311076552761105640    7400.0       34  7032056130
# ...

# %% [markdown]
# From here, we can see that they're 100, 000 transaction

# %%
data.columns
# Out:
# Index(['id', 'account_id', 'slug', 'transaction_no', 'amount', 'bank_id',
#        'account_no', 'transaction_cost', 'status', 'approved_by',
#        'approved_date', 'transfer_code', 'beneficiary_kyc_level',
#        'account_name_enquiry_reference', 'beneficiary_bvn', 'user_id',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
transaction_data = data[['account_id', 'amount', 'status', 'created_at']]

# %%
transaction_data['created_at'] = pd.to_datetime(transaction_data['created_at'], format = '%d/%m/%Y %H:%M')
transaction_data = transaction_data.rename(columns={'account_id': 'AccountID', 'amount': 'TransactionAmount', 'status': 'Status', 'created_at': 'DatePeriod'}) #.rename_axis('DateTime')
transaction_data.set_index('DatePeriod', inplace=True)
# Out:
# /tmp/ipykernel_19335/101098268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_data['created_at'] = pd.to_datetime(transaction_data['created_at'], format = '%d/%m/%Y %H:%M')

# %%
transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100000 entries, 2023-11-07 10:58:00 to 2023-04-30 04:59:00
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   AccountID          100000 non-null  int64
#  1   TransactionAmount  100000 non-null  float64
#  2   Status             100000 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.1+ MB

# %%
transaction_data
# Out:
#                      AccountID  TransactionAmount Status
# DatePeriod
# 2023-11-07 10:58:00     405126           500000.0   sent
# 2023-11-07 10:56:00     378829             7400.0   sent
# 2023-11-07 10:56:00     405469             3000.0   sent
# 2023-11-07 10:56:00       2262             2000.0   sent
# 2023-11-07 10:54:00     402063             1300.0   sent
# ...                        ...                ...    ...
# 2023-04-30 05:42:00     364922              583.0   sent
# 2023-04-30 05:33:00     364922             3525.0   sent
# 2023-04-30 05:13:00     353700             2000.0   sent
# 2023-04-30 05:00:00     178277             6000.0   sent
# 2023-04-30 04:59:00     353700             3000.0   sent
#
# [100000 rows x 3 columns]

# %%
print(transaction_data.AccountID.nunique())
print(transaction_data.Status.nunique())
print(transaction_data.Status.unique())
# Out:
# 3123
# 4
# ['sent' 'pending' 'failed' 'confirmed']

# %%
transaction_data.isna().sum()
# Out:
# AccountID            0
# TransactionAmount    0
# Status               0
# dtype: int64

# %%
transaction_data.to_csv("../data/cleaned_data.csv")
